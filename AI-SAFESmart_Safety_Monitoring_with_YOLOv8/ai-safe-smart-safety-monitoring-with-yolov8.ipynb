# %% [markdown]
# <!-- Header: Project Introduction -->
# <div style="background: linear-gradient(to right, #263238, #4db6ac); padding: 16px 22px; border-radius: 12px; font-size: 1.6em; font-weight: bold; color: white; box-shadow: 0 4px 10px rgba(0,0,0,0.15); margin-bottom: 18px;">
# 🛡️ AI-SAFE: Smart PPE Violation Detection with YOLOv8
# </div>

# %% [markdown]
# ![dreamina-2025-07-09-4939-A smart construction site monitored by A....jpeg](attachment:1fb51b8d-52b0-49b5-934a-a2270aed8c71.jpeg)

# %% [markdown]
# <p style="line-height: 1.7; font-size: 16px;">
# <strong>AI-SAFE</strong> is a real-world computer vision system designed to ensure occupational safety in high-risk environments such as construction sites and factories. Using the <strong>YOLOv8</strong> object detection model, this project automatically monitors whether individuals are wearing essential <strong>Personal Protective Equipment (PPE)</strong>, including:
# </p>
#
# <ul style="line-height: 1.7; font-size: 16px;">
#   <li>🪖 Helmet</li>
#   <li>👕 Safety Vest</li>
#   <li>🧤 Gloves</li>
#   <li>😷 Face Mask</li>
#   <li>🥽 Goggles</li>
# </ul>
#
# <p style="font-size: 16px;">
# It detects missing equipment like <code>no-helmet</code> or <code>no-vest</code>, logs violations automatically, and visualizes safety trends over time — all powered by a deep learning pipeline.
# </p>
#
# <!-- Real-world Scenario -->
# <div style="background: linear-gradient(to right, #37474f, #81d4fa); padding: 12px 20px; border-radius: 10px; font-size: 1.4em; font-weight: bold; color: white; margin-top: 30px; margin-bottom: 10px;">
# 🎬 Real-World Use Case
# </div>
#
# <p style="line-height: 1.7; font-size: 16px;">
# A large construction project by <strong>X Holding</strong> employs hundreds of field workers and dozens of surveillance cameras. Manual footage inspection is inefficient and error-prone. With <strong>AI-SAFE</strong>, camera feeds are analyzed in real-time, and violations are:
# </p>
# <ul style="line-height: 1.7; font-size: 16px;">
#   <li>⚠️ Detected instantly</li>
#   <li>📁 Logged with image names and timestamps</li>
#   <li>📊 Analyzed to generate time-based reports</li>
# </ul>
#
# <!-- Project Goals -->
# <div style="background: linear-gradient(to right, #1b5e20, #66bb6a); padding: 12px 20px; border-radius: 10px; font-size: 1.4em; font-weight: bold; color: white; margin-top: 30px; margin-bottom: 10px;">
# ✅ Project Goals
# </div>
#
# <ul style="line-height: 1.7; font-size: 16px;">
#   <li>📦 Train a YOLOv8 model on a custom PPE dataset</li>
#   <li>🔍 Detect PPE and violations in test images or videos</li>
#   <li>🧾 Log violations such as <code>no-helmet</code> or <code>no-goggles</code> into CSV</li>
#   <li>📈 Visualize violations using bar charts and time-series plots</li>
#   <li>📤 Export the model in formats like <code>.onnx</code>, <code>.tflite</code>, and <code>.torchscript</code> for deployment</li>
# </ul>
#
# <!-- Project Impact -->
# <div style="background: linear-gradient(to right, #ff6f00, #ffd54f); padding: 12px 20px; border-radius: 10px; font-size: 1.4em; font-weight: bold; color: #3e2723; margin-top: 30px; margin-bottom: 10px;">
# 🚀 Why This Matters
# </div>
#
# <ul style="line-height: 1.7; font-size: 16px;">
#   <li>🏗️ <strong>Industry Impact</strong>: Real-time monitoring increases on-site safety and reduces accidents</li>
#   <li>🧠 <strong>Technical Depth</strong>: Combines object detection, violation logging, and time-series analysis</li>
#   <li>🌍 <strong>Scalability</strong>: Suitable for factories, warehouses, or any environment requiring PPE enforcement</li>
# </ul>
#
# <!-- Closing Quote -->
# <blockquote style="background-color: #fff8e1; color: #e65100; padding: 14px 22px; border-left: 5px solid #ff9800; font-style: italic; font-size: 15px; margin-top: 30px;">
# 💡 <strong>AI-SAFE bridges deep learning and workplace safety — transforming video footage into actionable safety intelligence.</strong>
# </blockquote>

# %% [markdown]
# # 🔧 YOLOv8 Environment Setup and Model Training

# %%
with open("/kaggle/input/ppe-dedection/data.yaml", "r") as f:
    print(f.read())
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 6
# names: ['boots', 'gloves', 'goggles', 'helmet', 'person', 'vest']
#
# roboflow:
#   workspace: rbyz
#   project: ppe-6-classes-ntld9
#   version: 6
#   license: MIT
#   url: https://universe.roboflow.com/rbyz/ppe-6-classes-ntld9/dataset/6

# %%
# !pip install ultralytics --quiet
from ultralytics import YOLO
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 97.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.1 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# ...

# %%
# !yolo task=detect \
  mode=train \
  model=yolov8n.pt \
  data=/kaggle/input/ppe-dedection/data.yaml \
  epochs=50 \
  imgsz=640 \
  batch=16 \
  workers=4 \
  cache=ram \
  name=yolov8n-ppe-v2 \
  save=True \
  save_period=5 \
  patience=10 \
  project=/kaggle/working \
  amp=True \
  optimizer="auto" \
  pretrained=True \
  device=0
# Out:
# ...
# 100%|██████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 18.6MB/s]
# Ultralytics 8.3.163 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
import pandas as pd

data = {
    "Class": ["all", "boots", "gloves", "goggles", "helmet", "person", "vest"],
    "Images": [1669, 442, 279, 604, 534, 306, 572],
    "Labels": [6507, 1276, 653, 875, 1464, 784, 1455],
    "Precision": [0.532, 0.581, 0.459, 0.639, 0.562, 0.377, 0.573],
    "Recall": [0.565, 0.503, 0.352, 0.626, 0.680, 0.579, 0.646],
    "mAP@0.5": [0.509, 0.544, 0.317, 0.655, 0.569, 0.334, 0.635],
    "mAP@0.5:0.95": [0.374, 0.395, 0.218, 0.459, 0.425, 0.243, 0.502]
}

df_metrics = pd.DataFrame(data)

df_metrics
# Out:
#      Class  Images  Labels  Precision  Recall  mAP@0.5  mAP@0.5:0.95
# 0      all    1669    6507      0.532   0.565    0.509         0.374
# 1    boots     442    1276      0.581   0.503    0.544         0.395
# 2   gloves     279     653      0.459   0.352    0.317         0.218
# 3  goggles     604     875      0.639   0.626    0.655         0.459
# 4   helmet     534    1464      0.562   0.680    0.569         0.425
# 5   person     306     784      0.377   0.579    0.334         0.243
# 6     vest     572    1455      0.573   0.646    0.635         0.502

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams.update({
    'axes.titlesize': 14,
    'axes.labelsize': 12,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10
})

fig, axes = plt.subplots(2, 2, figsize=(16, 10))
metrics = ['Precision', 'Recall', 'mAP@0.5', 'mAP@0.5:0.95']
palette = "Set2"

for ax, metric in zip(axes.flat, metrics):
    sns.barplot(
        x=metric,
        y='Class',
        data=df_metrics.sort_values(by=metric, ascending=True),
        ax=ax,
        palette=palette
    )
    ax.set_title(f"{metric} per Class")
    ax.set_xlim(0, 1)
    ax.grid(True, linestyle='--', linewidth=0.5)

plt.tight_layout()
plt.savefig("yolov8_class_metrics_from_df_metrics.png")
plt.show()

# %%
df = pd.read_csv('/kaggle/working/yolov8n-ppe-v2/results.csv')

print(df.columns.tolist())

metrics = [
    ('train/box_loss', 'Train Box Loss'),
    ('train/cls_loss', 'Train Class Loss'),
    ('train/dfl_loss', 'Train DFL Loss'),
    ('val/box_loss', 'Val Box Loss'),
    ('val/cls_loss', 'Val Class Loss'),
    ('val/dfl_loss', 'Val DFL Loss'),
    ('metrics/precision(B)', 'Precision'),
    ('metrics/recall(B)', 'Recall'),
    ('metrics/mAP50(B)', 'mAP@0.5'),
    ('metrics/mAP50-95(B)', 'mAP@0.5:0.95'),
]

plt.rcParams.update({
    'font.size': 14,
    'axes.titlesize': 16,
    'axes.labelsize': 14,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'legend.fontsize': 12
})

plt.figure(figsize=(22, 28))
for i, (col, title) in enumerate(metrics, 1):
    plt.subplot(5, 2, i)
    plt.plot(df[col], label=title, marker='o')
    plt.title(title)
    plt.xlabel("Epoch")
    plt.ylabel("Value")
    plt.grid(True, linestyle='--', linewidth=0.5)
    plt.legend(loc='best')

plt.tight_layout()
plt.show()
# Out:
# ['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss', 'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss', 'lr/pg0', 'lr/pg1', 'lr/pg2']

# %%
from IPython.display import Image, display

display(Image(filename="/kaggle/working/yolov8n-ppe-v2/confusion_matrix.png"))

# %% [markdown]
# # 🎯 Inference on Test Images

# %%
# !yolo task=detect \
  mode=predict \
  model=/kaggle/working/yolov8n-ppe-v2/weights/best.pt \
  source=/kaggle/input/ppe-dedection/test/images \
  imgsz=640 \
  conf=0.25 \
  save=True \
  save_txt=True \
  project=/kaggle/working \
  name=predict_ppe
# Out:
# Ultralytics 8.3.163 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1646 /kaggle/input/ppe-dedection/test/images/000000465549_jpg.rf.7e52723763a8cdea6d47a2b9ddb3bd50.jpg: 640x640 1 goggles, 6.4ms
# image 2/1646 /kaggle/input/ppe-dedection/test/images/00000383_jpg.rf.7c79431417c4a6daf45440914726bff8.jpg: 640x640 (no detections), 6.2ms
# image 3/1646 /kaggle/input/ppe-dedection/test/images/00000383_jpg.rf.c7a9386a0826029b251a1b02c56ecdf8.jpg: 640x640 1 goggles, 1 helmet, 5.9ms
# image 4/1646 /kaggle/input/ppe-dedection/test/images/000004_jpg.rf.b69f27cc38c6350af4f7e20e789ab820.jpg: 640x640 2 helmets, 5.7ms
# image 5/1646 /kaggle/input/ppe-dedection/test/images/000007_jpg.rf.82be78a1c13428e04661b26289008b07.jpg: 640x640 2 helmets, 3 persons, 6.0ms
# ...

# %%
from IPython.display import Image, display
import os

prediction_dir = "/kaggle/working/predict_ppe"

image_files = [f for f in os.listdir(prediction_dir) if f.endswith(('.jpg', '.png'))][:3]

for img_file in image_files:
    display(Image(filename=os.path.join(prediction_dir, img_file)))

# %% [markdown]
# # 📊 Violation Logging and Statistical Analysis

# %%
labels_dir = "/kaggle/working/predict_ppe/labels"

class_names = ['Gloves', 'Goggles', 'Helmet', 'No-Gloves', 'No-Goggles', 'No-Helmet', 'Person']

violation_keywords = ["no-"]
violation_counts = {}

for file in os.listdir(labels_dir):
    if file.endswith(".txt"):
        with open(os.path.join(labels_dir, file), 'r') as f:
            lines = f.readlines()
            for line in lines:
                class_index = int(line.strip().split()[0])
                class_name = class_names[class_index]
                if any(keyword.lower() in class_name.lower() for keyword in violation_keywords):
                    violation_counts[class_name] = violation_counts.get(class_name, 0) + 1

df_violations = pd.DataFrame(list(violation_counts.items()), columns=["Violation Class", "Count"])
df_violations = df_violations.sort_values(by="Count", ascending=False)

if not df_violations.empty:
    plt.figure(figsize=(10,6))
    sns.barplot(data=df_violations, x="Violation Class", y="Count", palette="Reds_r")
    plt.title(" PPE Violation Frequency", fontsize=16)
    plt.xlabel("Violation Type")
    plt.ylabel("Count")
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("⚠️ No violation classes were detected. Please check your tags and class names.")

# %%
class_names = ['boots', 'gloves', 'goggles', 'helmet', 'person', 'vest']
required_ppe = ['gloves', 'goggles', 'helmet', 'vest'] 

labels_dir = "/kaggle/working/predict_ppe/labels"
image_dir = "/kaggle/input/ppe-dedection/test/images"

violations = []

for label_file in os.listdir(labels_dir):
    if not label_file.endswith(".txt"):
        continue

    img_name = label_file.replace(".txt", ".jpg")

    with open(os.path.join(labels_dir, label_file), "r") as f:
        lines = f.readlines()
        detected_classes = [class_names[int(line.split()[0])] for line in lines]

    for ppe in required_ppe:
        if ppe not in detected_classes:
            violations.append({
                "Image": img_name,
                "Violation Class": f"no-{ppe}"
            })

df_violations = pd.DataFrame(violations)
df_violations.to_csv("/kaggle/working/ppe_violations_log.csv", index=False)
df_violations.head()
# Out:
#                                                Image Violation Class
# 0  432977d478ed8c095a95b0a34dcc8d1a_jpg.rf.1979a9...       no-gloves
# 1  432977d478ed8c095a95b0a34dcc8d1a_jpg.rf.1979a9...      no-goggles
# 2  432977d478ed8c095a95b0a34dcc8d1a_jpg.rf.1979a9...       no-helmet
# 3  432977d478ed8c095a95b0a34dcc8d1a_jpg.rf.1979a9...         no-vest
# 4  image_252_jpg.rf.58553160b207981d3235978a24e22...       no-helmet

# %% [markdown]
# ## 🧪 Performance Analysis per Class

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df_violations, y="Violation Class", order=df_violations["Violation Class"].value_counts().index, palette="Reds_r")
plt.title("PPE Violation Frequency", fontsize=16)
plt.xlabel("Count")
plt.ylabel("Violation Type")
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## The most violated images (top 10 images)

# %%
df_violations["Short Name"] = df_violations["Image"].apply(lambda x: x.split("_jpg")[0] + ".jpg")

top_images = df_violations["Short Name"].value_counts().nlargest(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_images.values, y=top_images.index, palette="Oranges_r")
plt.title("Images with Most PPE Violations", fontsize=16)
plt.xlabel("Violation Count")
plt.ylabel("Image")
plt.grid(axis="x", linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 📈 Time-Series and Trend Analysis

# %%
import pandas as pd
import numpy as np
import datetime as dt

# 📌 Sample date range (7-day simulation)
start_date = dt.datetime(2024, 7, 1, 8)  # Start: July 1st 08:00
timestamps = [start_date + dt.timedelta(minutes=np.random.randint(0, 7*24*60))
              for _ in range(len(df_violations))]

df_violations["Timestamp"] = timestamps
df_violations["Hour"] = df_violations["Timestamp"].dt.hour
df_violations["Date"] = df_violations["Timestamp"].dt.date

df_violations["Timestamp"] = df_violations["Timestamp"].dt.strftime("%Y-%m-%d %H:%M")

df_violations = df_violations[["Short Name", "Violation Class", "Timestamp", "Hour", "Date"]]

styled_df = df_violations.head().style.set_properties(**{
    'font-size': '14px',
    'border-color': 'black',
    'border-width': '1px',
    'text-align': 'center'
}).set_table_styles([
    {'selector': 'th', 'props': [('background-color', '#4E79A7'), ('color', 'white'), ('font-size', '14px')]},
    {'selector': 'td', 'props': [('padding', '6px')]}
]).map(lambda val: 'background-color: #FFB3B3' if isinstance(val, str) and "no-" in val else '')

styled_df
# Out:
# <style type="text/css">
# #T_fca11 th {
#   background-color: #4E79A7;
#   color: white;
#   font-size: 14px;
# }
# #T_fca11 td {
#   padding: 6px;
# }
# #T_fca11_row0_col0, #T_fca11_row0_col2, #T_fca11_row0_col3, #T_fca11_row0_col4, #T_fca11_row1_col0, #T_fca11_row1_col2, #T_fca11_row1_col3, #T_fca11_row1_col4, #T_fca11_row2_col0, #T_fca11_row2_col2, #T_fca11_row2_col3, #T_fca11_row2_col4, #T_fca11_row3_col0, #T_fca11_row3_col2, #T_fca11_row3_col3, #T_fca11_row3_col4, #T_fca11_row4_col0, #T_fca11_row4_col2, #T_fca11_row4_col3, #T_fca11_row4_col4 {
#   font-size: 14px;
#   border-color: black;
#   border-width: 1px;
#   text-align: center;
# }
# #T_fca11_row0_col1, #T_fca11_row1_col1, #T_fca11_row2_col1, #T_fca11_row3_col1, #T_fca11_row4_col1 {
#   font-size: 14px;
#   border-color: black;
#   border-width: 1px;
#   text-align: center;
#   background-color: #FFB3B3;
# }
# </style>
# <table id="T_fca11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df_violations, x="Hour", palette="coolwarm")
plt.title(" PPE Violations by Hour of Day", fontsize=16)
plt.xlabel("Hour of Day")
plt.ylabel("Number of Violations")
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
daily_counts = df_violations.groupby("Date").size()

plt.figure(figsize=(10,5))
daily_counts.plot(marker="o", linestyle="-", color="darkred")
plt.title("Total PPE Violations per Day", fontsize=16)
plt.xlabel("Date")
plt.ylabel("Total Violations")
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import random
from PIL import Image as PILImage

prediction_dir = "/kaggle/working/predict_ppe"
img_size = (224, 224)
grid_rows, grid_cols = 2, 3 
font_size = 8

selected_classes = ["no-helmet", "no-vest", "no-goggles", "no-gloves"]
filtered_df = df_violations[df_violations["Violation Class"].isin(selected_classes)]

matched = []
for idx, row in filtered_df.iterrows():
    short_name = row["Short Name"].replace(".jpg", "")
    for fname in os.listdir(prediction_dir):
        if short_name in fname:
            matched.append({
                "file": fname,
                "violation": row["Violation Class"],
                "timestamp": f"{row['Date']} {row['Hour']}:00"
            })
            break

random.shuffle(matched)
selected = matched[:grid_rows * grid_cols]

fig, axs = plt.subplots(grid_rows, grid_cols, figsize=(grid_cols * 3, grid_rows * 3))
fig.suptitle(" PPE Violations Summary", fontsize=14, color="#D32F2F", weight="bold")

for ax, entry in zip(axs.flat, selected):
    img_path = os.path.join(prediction_dir, entry["file"])
    img = PILImage.open(img_path).resize(img_size)
    ax.imshow(img)
    ax.set_title(f"{entry['timestamp']}", fontsize=font_size, color='darkblue')
    ax.set_xlabel(f" {entry['violation']}", fontsize=font_size, color='darkred')
    ax.axis('off')

for i in range(len(selected), grid_rows * grid_cols):
    axs.flat[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 📤 Model Export & Deployment

# %%
model_path = "/kaggle/working/yolov8n-ppe-v2/weights/best.pt"

# %%
# We give the path of the trained model
model = YOLO("/kaggle/working/yolov8n-ppe-v2/weights/best.pt")

# Export as ONNX
model.export(format="onnx")
# Out:
# Ultralytics 8.3.163 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/kaggle/working/yolov8n-ppe-v2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 10, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<1.18.0', 'onnxslim>=0.1.59', 'onnxruntime'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 9.4s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.59...
# ONNX: export success ✅ 13.5s, saved as '/kaggle/working/yolov8n-ppe-v2/weights/best.onnx' (11.7 MB)
#
# Export complete (14.0s)
# ...

# %%
model.export(format="tflite") # For mobile devices
model.export(format="torchscript") # For PyTorch deploy
# Out:
# Ultralytics 8.3.163 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/kaggle/working/yolov8n-ppe-v2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 10, 8400) (6.0 MB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752144160.160608      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752144160.212048      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0,<1.4.0', 'onnx2tf>=1.26.3', 'protobuf>=5'] not found, attempting AutoUpdate...
#
# ...

# %% [markdown]
# <!-- Final Report Header -->
# <div style="background: linear-gradient(to right, #263238, #4db6ac); padding: 16px 22px; border-radius: 12px; font-size: 1.6em; font-weight: bold; color: white; box-shadow: 0 4px 10px rgba(0,0,0,0.15); margin-bottom: 18px;">
# ✅ Final Report: AI-SAFE – YOLOv8-Based PPE Violation Detection
# </div>
#
# <!-- Objective -->
# <div style="background: linear-gradient(to right, #1e88e5, #90caf9); padding: 12px 20px; border-radius: 10px; font-size: 1.4em; font-weight: bold; color: white; margin-top: 20px;">
# 🎯 Project Objective
# </div>
#
# <p style="line-height: 1.7; font-size: 16px;">
# <strong>AI-SAFE</strong> is a real-time computer vision solution designed to enhance occupational safety by monitoring PPE usage in industrial and construction environments. Leveraging <strong>YOLOv8</strong>, the system detects missing safety equipment such as <code>helmet</code>, <code>vest</code>, <code>gloves</code>, and <code>goggles</code> — ensuring compliance and enabling proactive intervention.
# </p>
#
# <!-- Workflow Summary -->
# <div style="background: linear-gradient(to right, #2e7d32, #81c784); padding: 12px 20px; border-radius: 10px; font-size: 1.4em; font-weight: bold; color: white; margin-top: 30px;">
# 🔧 Project Workflow Summary
# </div>
#
# <table style="width: 100%; border-collapse: collapse; font-size: 15px; margin-top: 10px;">
#   <thead style="background-color: #e8f5e9; color: #1b5e20;">
#     <tr>
#       <th style="text-align: left; padding: 10px; border-bottom: 2px solid #c8e6c9;">Step</th>
#       <th style="text-align: left; padding: 10px; border-bottom: 2px solid #c8e6c9;">Description</th>
#     </tr>
#   </thead>
#   <tbody style="color: #2e7d32;">
#     <tr><td style="padding: 10px;">1️⃣</td><td style="padding: 5px;">Defined the project scope and created a real-world safety monitoring scenario</td></tr>
#     <tr><td style="padding: 10px;">2️⃣</td><td style="padding: 5px;">Explored and structured the PPE dataset; prepared <code>data.yaml</code></td></tr>
#     <tr><td style="padding: 10px;">3️⃣</td><td style="padding: 5px;">Installed and configured the YOLOv8 environment in Kaggle</td></tr>
#     <tr><td style="padding: 10px;">4️⃣</td><td style="padding: 5px;">Trained a YOLOv8 model and saved the best weights</td></tr>
#     <tr><td style="padding: 10px;">5️⃣</td><td style="padding: 5px;">Performed inference on test images and visualized predictions</td></tr>
#     <tr><td style="padding: 10px;">6️⃣</td><td style="padding: 5px;">Logged detected PPE violations (e.g., <code>no-helmet</code>) into a CSV file</td></tr>
#     <tr><td style="padding: 10px;">7️⃣</td><td style="padding: 5px;">Analyzed time-based violation trends using visualizations</td></tr>
#     <tr><td style="padding: 10px;">8️⃣</td><td style="padding: 5px;">Exported the model in <code>.onnx</code> format for edge deployment</td></tr>
#   </tbody>
# </table>
#
# <!-- Observations -->
# <div style="background: linear-gradient(to right, #6a1b9a, #ab47bc); padding: 12px 20px; border-radius: 10px; font-size: 1.4em; font-weight: bold; color: white; margin-top: 30px;">
# 📊 Performance & Observations
# </div>
#
# <ul style="line-height: 1.7; font-size: 16px;">
#   <li>✅ Violations were successfully detected and labeled</li>
#   <li>📈 Daily and hourly violation statistics were generated</li>
#   <li>📸 Top violating images were identified</li>
#   <li>⏱️ Time-based violation patterns were clearly visualized</li>
# </ul>
# <p><strong>Logged examples:</strong> <code>no-helmet</code>, <code>no-vest</code>, <code>no-goggles</code>, <code>no-gloves</code></p>
#
# <!-- Model Evaluation -->
# <div style="background: linear-gradient(to right, #1565c0, #64b5f6); padding: 12px 20px; border-radius: 10px; font-size: 1.4em; font-weight: bold; color: white; margin-top: 30px;">
# 📈 Model Evaluation (YOLOv8)
# </div>
#
# <table style="width: 100%; border-collapse: collapse; font-size: 15px; margin-top: 10px;">
#   <thead style="background-color: #e3f2fd; color: #0d47a1;">
#     <tr>
#       <th style="padding: 10px; border-bottom: 2px solid #bbdefb;">Metric</th>
#       <th style="padding: 10px; border-bottom: 2px solid #bbdefb;">Value</th>
#     </tr>
#   </thead>
#   <tbody style="color: #1565c0;">
#     <tr><td style="padding: 10px;">mAP@0.5</td><td style="padding: 5px;">0.635</td></tr>
#     <tr><td style="padding: 10px;">Precision</td><td style="padding: 5px;">0.573</td></tr>
#     <tr><td style="padding: 10px;">Recall</td><td style="padding: 5px;">0.646</td></tr>
#   </tbody>
# </table>
#
# <blockquote style="background-color: #fff8e1; color: #e65100; padding: 14px 22px; border-left: 5px solid #ff9800; font-style: italic; font-size: 15px; margin-top: 20px;">
# 📌 <strong>Note:</strong> Further dataset balancing and augmentation could improve these metrics.
# </blockquote>
#
# <!-- Future Work -->
# <div style="background: linear-gradient(to right, #f4511e, #ffb74d); padding: 12px 20px; border-radius: 10px; font-size: 1.4em; font-weight: bold; color: white; margin-top: 30px;">
# 🔮 Future Development Ideas
# </div>
#
# <ul style="line-height: 1.7; font-size: 16px;">
#   <li>🎥 Real-time video stream detection using OpenCV</li>
#   <li>🚨 Live alert system for on-site safety officers</li>
#   <li>📊 Web dashboard with real-time metrics and violation logs</li>
#   <li>📦 Deployment on low-power edge devices like Raspberry Pi or Jetson Nano</li>
# </ul>
#
# <!-- Project Artifacts Header -->
# <div style="background: linear-gradient(to right, #0d47a1, #42a5f5); padding: 14px 20px; border-radius: 10px; font-size: 1.5em; font-weight: bold; color: white; margin-top: 30px; margin-bottom: 10px;">
# 📁 Project Artifacts
# </div>
#
# <!-- Project Artifacts Table -->
# <table style="width: 100%; border-collapse: collapse; font-size: 15px; border-radius: 8px; overflow: hidden; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
#   <thead style="background-color: #e3f2fd; color: #0d47a1;">
#     <tr>
#       <th style="text-align: left; padding: 12px; border-bottom: 2px solid #90caf9;">File / Output</th>
#       <th style="text-align: left; padding: 12px; border-bottom: 2px solid #90caf9;">Path</th>
#     </tr>
#   </thead>
#   <tbody style="color: #0d47a1;">
#     <tr>
#       <td style="padding: 10px;">ONNX Model</td>
#       <td style="padding: 10px; background-color: #edf4fb;"><code>/kaggle/working/yolov8n-ppe-v2/weights/best.onnx</code></td>
#     </tr>
#     <tr>
#       <td style="padding: 10px;">TorchScript Model</td>
#       <td style="padding: 10px; background-color: #edf4fb;"><code>/kaggle/working/yolov8n-ppe-v2/weights/best.torchscript</code></td>
#     </tr>
#     <tr>
#       <td style="padding: 10px;">TFLite Model</td>
#       <td style="padding: 10px; background-color: #edf4fb;"><code>/kaggle/working/yolov8n-ppe-v2/weights/best_saved_model/best_float32.tflite</code></td>
#     </tr>
#     <tr>
#       <td style="padding: 10px;">Prediction Results (Images)</td>
#       <td style="padding: 10px; background-color: #edf4fb;"><code>/kaggle/working/predict_ppe/</code></td>
#     </tr>
#     <tr>
#       <td style="padding: 10px;">Violation Log (CSV)</td>
#       <td style="padding: 10px; background-color: #edf4fb;"><code>/kaggle/working/ppe_violations_log.csv</code></td>
#     </tr>
#     <tr>
#       <td style="padding: 10px;">Class Metrics (CSV)</td>
#       <td style="padding: 10px; background-color: #edf4fb;"><code>/kaggle/working/yolov8_class_metrics_from_df.csv</code></td>
#     </tr>
#   </tbody>
# </table>
#
# <!-- Conclusion -->
# <div style="background: linear-gradient(to right, #263238, #4db6ac); padding: 14px 22px; border-radius: 10px; font-size: 1.4em; font-weight: bold; color: white; margin-top: 30px;">
# 🏁 Conclusion
# </div>
#
# <p style="line-height: 1.7; font-size: 16px;">
# The <strong>AI-SAFE</strong> project demonstrates how modern deep learning models like <strong>YOLOv8</strong> can be applied to real-world safety monitoring tasks. From detection to reporting and trend analysis, it presents a scalable, automated, and practical framework for improving occupational safety across diverse industrial settings.
# </p>

# %% [markdown]
# <div style="
#   background: linear-gradient(to right, #e0f7fa, #b2ebf2);
#   padding: 20px;
#   border-radius: 12px;
#   color: #006064;
#   font-size: 16px;
#   line-height: 1.7;
#   box-shadow: 0 3px 10px rgba(0,0,0,0.08);
#   margin-top: 30px;
#   border: 1px solid #4dd0e1;
# ">
#
#   <h1 style="color: #00796b; margin-top: 0;">🤝 Support & Feedback</h1>
#
#
#   <p>If you found this notebook <strong>useful</strong>, <strong>insightful</strong>, or <strong>inspiring</strong>, consider:</p>
#
#   <ul>
#     <li>⭐️ <strong>Upvoting</strong> to support and highlight the work</li>
#     <li>💬 <strong>Leaving a comment</strong> — ideas, questions, or feedback are always appreciated</li>
#     <li>🔁 <strong>Forking</strong> this notebook to create your own version</li>
#   </ul>
#
#   <p>Your engagement helps keep this open-source initiative <strong>growing, learning, and improving</strong> 🚀
#   <br>Thank you for being part of this journey!</p>
#
#   <blockquote style="
#     background-color: #b2ebf2;
#     border-left: 5px solid #00acc1;
#     padding: 12px 18px;
#     margin-top: 20px;
#     font-style: italic;
#     color: #004d40;">
#     <em>AI for safety — because every second matters. ⏱️🛡️</em>
#   </blockquote>
#
# </div>
